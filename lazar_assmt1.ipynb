# %% [markdown]
# # Assignment on Python for Data Science

# %% [markdown]
# ## 1. Read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
df = pd.read_csv(r'C:\Users\asus\Desktop\ictka\iris.csv')

# %% [markdown]
# ## 2. Display the columns in the dataset

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 3. Calculate the mean of each column of the dataset

# %%
df.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df_numeric = df[['SL', 'SW', 'PL', 'PW']]
df_numeric
# Out:
#       SL   SW   PL   PW
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [150 rows x 4 columns]

# %%
df_numeric.mean(axis=0)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# ## 4. Check for null values in the dataset

# %%
df.isna().value_counts()
# Out:
# SL     SW     PL     PW     Classification
# False  False  False  False  False             150
# dtype: int64

# %%
df.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# ### There are no null values in the dataset

# %% [markdown]
# # 5. Perform meaningful visualizations using the database

# %% [markdown]
# # Histograms of numerical columns

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)

plt.hist(df['SL'],bins=10,edgecolor='y',color='g')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
#plt.title('Histogram of Sepal Length')

plt.subplot(2,2,2)
plt.hist(df['SW'],bins=10,edgecolor='y',color='g')
plt.xlabel('Sepal Width')
plt.ylabel('Frequency')
#plt.title('Histogram of Sepal Width')

plt.subplot(2,2,3)
plt.hist(df['PL'],bins=10,edgecolor='y',color='g')
plt.xlabel('Petal Length')
plt.ylabel('Frequency')
#plt.title('Histogram of Petal Length')

plt.subplot(2,2,4)
plt.hist(df['PW'],bins=10,edgecolor='y',color='g')
plt.xlabel('Petal Width')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Histograms shown above suggests that SL, SW and PL column values follow approximately normal distribution, whereas, PW column values do not follow normal distribution.

# %% [markdown]
# ## Box Plots

# %%
plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
sns.boxplot(x = 'Classification', y='SL', data = df)

plt.subplot(2,2,2)
sns.boxplot(x = 'Classification', y='SW', data = df)

plt.subplot(2,2,3)
sns.boxplot(x = 'Classification', y='PL', data = df)


plt.subplot(2,2,4)
sns.boxplot(x = 'Classification', y='PW', data = df)
plt.show()

# %% [markdown]
# ## Correlation Plot

# %%
sns.heatmap(data=df.corr(),annot=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_10480\3803735512.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ### Correlation plot shows that Length and width of Sepal of Iris flower Sepal have strong relationship with the lenth and width of their Petal

# %% [markdown]
# ## Scatter Plots

# %%
sns.scatterplot(x='SL',y='SW',hue='Classification',data=df)
# Out:
# <Axes: xlabel='SL', ylabel='SW'>

# %%
sns.scatterplot(x='PL',y='PW',hue='Classification',data=df)
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %%
sns.scatterplot(x='PL',y='PW',hue='Classification',data=df)
# Out:
# <Axes: xlabel='PL', ylabel='PW'>

# %% [markdown]
# ### From the two plots above, we can infer that the sepal-petal size ratio of class Iris-seltosa is the highest among the three classes.

# %%
plt.figure(figsize=(10,6))

plt.subplot(2,1,1)
sns.lineplot(x='SL',y='SW',hue='Classification',data=df)
plt.subplot(2,1,2)
sns.lineplot(x='PL',y='PW',hue='Classification',data=df)
plt.show()
